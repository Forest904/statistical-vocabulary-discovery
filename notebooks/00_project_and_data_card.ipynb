# %% [markdown]
# # 00 Project And Data Card
#
# Milestone 1 data card draft for the StatVocab core corpus. Run `statvocab acquire --config configs/core.yaml` and `statvocab ingest --config configs/core.yaml` before executing this notebook.

# %%
import json
from pathlib import Path

diagnostics_path = Path('../data/processed/ingestion_diagnostics.json')
diagnostics = (
    json.loads(diagnostics_path.read_text(encoding='utf-8'))
    if diagnostics_path.exists()
    else {}
)
diagnostics

# %% [markdown]
# ## Resource Summary
#
# This section records source URLs, versions, licenses, checksums, and validation status from the acquisition manifest.

# %%
diagnostics.get('resource_validation', [])
